# %% [markdown]
# <a href="https://colab.research.google.com/github/ShoaibMurtazaWb/Python/blob/main/Variables%20and%20Simple%20Data%20Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Python world!")
# Out:
# Hello Python world!

# %% [markdown]
# # **Variables**
# A variable is a symbolic name (or label) that references an object or value stored in the computer's memory.
#
# Variables are created using the assignment operator (=).
#
# Syntax: *`variable_name = value`*

# %%
message = "Hello Python world!"
print(message)
# Out:
# Hello Python world!

# %%
message = "Hello Python Crash Course world!"
print(message)
# Out:
# Hello Python Crash Course world!

# %% [markdown]
# ### **Naming and Using Variables**

# %% [markdown]
# - Variable names can contain only letters, numbers, and underscores.<br>
# They can start with a letter or an underscore, but not with a number.
# For instance, you can call a variable `message_1` but not `1_message`.
#
# - Spaces are not allowed in variable names, but underscores can be used
# to separate words in variable names. For example, `greeting_message`
# works, but `greeting message` will cause errors.
#
# - Avoid using Python **keywords** and **function names** as variable names;
# that is, do not use words that *Python has reserved for a particular programmatic purpose*, such as the word `print`.
#
# -	Variable names should be short but descriptive.<br>
# For example, `name` is
# better than `n`, `student_name` is better than `s_n`, and `name_length` is better
# than `length_of_persons_name`.
#
# -	Be careful when using the lowercase letter(L) `l` and the uppercase letter(O) `O`
# because they could be confused with the numbers `1` and `0`.

# %% [markdown]
# ### **Avoiding Name Errors When Using Variables**
#
# A name error
# usually means we either forgot to ***set a variable’s value*** before using it, or
# we made a ***spelling mistake*** when entering the variable’s name.
#
# Every programmer makes mistakes, and most make mistakes every day.
# Although good programmers might create errors, they also know how to
# respond to those errors efficiently

# %%
message = "Hello Python Crash Course reader!"
print(mesage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-82042849.py in <cell line: 0>()
#       1 message = "Hello Python Crash Course reader!"
# ----> 2 print(mesage)
#
# NameError: name 'mesage' is not defined

# %% [markdown]
# **Ouput**
# ```
# Traceback (most recent call last):<br>
# 1- File "hello_world.py", line 2, in <module><br>
# 2- print(mesage)<br>
# 3- NameError: name 'mesage' is not defined
# ```
#
# The output at 1 reports that an error occurs in line 2 of the file
# hello_world.py. The interpreter shows this line 2 to help us spot the error
# quickly and tells us what kind of error it found 3 In this case it found a
# ***name error*** and reports that the variable being printed, mesage, has not been
# defined.

# %%
message = "Hello Python Crash Course reader!"
print(message)
# Out:
# Hello Python Crash Course reader!
